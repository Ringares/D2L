# %%
import torch
import torch.nn as nn
from torch.nn import functional as F 
import torchviz
import sys; sys.path.insert(0, '../')
from exp import nb_d2l_utils

# %%
torch.__version__
# Out:
# '1.3.1'

# %%
class DenseLayer(nn.Module):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate):
        """
        bn_size (int) - multiplicative factor for number of bottle neck layers
          (i.e. bn_size * k features in the bottleneck layer)
        """
        super().__init__()
        # bottle neck
        self.add_module('norm1', nn.BatchNorm2d(num_input_features))
        self.add_module('relu1', nn.ReLU(inplace=True))
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                                           growth_rate, kernel_size=1, stride=1,
                                           bias=False))
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate))
        self.add_module('relu2', nn.ReLU(inplace=True))
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                                           kernel_size=3, stride=1, padding=1,
                                           bias=False))
        self.drop_rate = float(drop_rate)
    
    def forward(self, x):
        if isinstance(x, torch.Tensor):
            prev_features = [x]
        else:
            prev_features = x
        x = torch.cat(prev_features, 1)
        x = self.conv1(self.relu1(self.norm1(x)))
        x = self.conv2(self.relu2(self.norm2(x)))
        if self.drop_rate > 0:
            x = F.dropout(x, self.drop_rate)
        return x
    
class DenseBlock(nn.Module):
    def __init__(self, num_layers, num_input_features, growth_rate, bn_size=4, drop_rate=0):
        super().__init__()
        for i in range(num_layers):
            layer = DenseLayer(
                num_input_features + i * growth_rate,
                growth_rate=growth_rate,
                bn_size=bn_size,
                drop_rate=drop_rate,
            )
            self.add_module('denselayer%d' % (i + 1), layer)
    
    def forward(self, x):
        features = [x]
        for l in self.children():
            y = l(features)
            features.append(y)
        return torch.cat(features, 1)

class Transition(nn.Sequential):
    def __init__(self, num_in_feat, num_out_feat):
        super().__init__()
        self.add_module('norm', nn.BatchNorm2d(num_in_feat))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_in_feat, num_out_feat, kernel_size=1, stride=1))
        self.add_module('avgpool', nn.AvgPool2d(kernel_size=2, stride=2))

# %%
DenseLayer(3, 16, 4, 0)(torch.randn((1,3,224,224))).shape
# Out:
# torch.Size([1, 16, 224, 224])

# %%
DenseBlock(2, 3, 16, 4, 0)(torch.randn((1,3,224,224))).shape
# Out:
# torch.Size([1, 35, 224, 224])

# %%
from collections import OrderedDict

class DenseNet(nn.Module):
    def __init__(self, num_init_features, block_config, growth_rate, num_classes=10, bn_size=4, drop_rate=0):
        super().__init__()
        self.features = nn.Sequential(
            OrderedDict([
                ('conv0', nn.Conv2d(3, num_init_features, kernel_size=7, stride=2, padding=3, bias=False)),
                ('norm0', nn.BatchNorm2d(num_init_features)),
                ('relu0', nn.ReLU(inplace=True)),
                ('max_pool0', nn.MaxPool2d(kernel_size=3, stride=2, padding=1)) # kernel=3, padding=1, 不能用 AdaptiveMaxPool2d
            ])
        )
        num_features = num_init_features
        for i, num_layer in enumerate(block_config):
            # dense block
            dense_block = DenseBlock(num_layer, num_features, growth_rate, bn_size, drop_rate)
            self.features.add_module('dense_block%d' % (i + 1), dense_block)
            num_features = num_features + num_layer*growth_rate
            # transition layer
            if i != len(block_config) - 1:
                trans_layer = Transition(num_features, num_features//2)
                self.features.add_module('transition%d' % (i + 1), trans_layer)
                num_features = num_features//2
        
        # 最后
        self.final = nn.Sequential(
            OrderedDict([
                ('norm5', nn.BatchNorm2d(num_features)),
                ('relu5', nn.ReLU(inplace=True)),
                ('avgpool5', nn.AdaptiveAvgPool2d(1)),
                ('flatten', nn.Flatten(1)),
                ('linear', nn.Linear(num_features, num_classes))
            ])
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.final(x)
        return x

# %%
model = DenseNet(64, (6, 12, 24, 16), 32)

# %%
model
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (max_pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (dense_block1): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense_block2): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense_block3): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (dense_block4): DenseBlock(
#       (denselayer1): DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (final): Sequential(
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu5): ReLU(inplace=True)
#     (avgpool5): AdaptiveAvgPool2d(output_size=1)
#     (flatten): Flatten()
#     (linear): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )

# %%
x = torch.randn((1,3,224,224))

# %%
model(x).shape
# Out:
# torch.Size([1, 10])

# %%
def remove_sequential(network, all_layers=None):
    if all_layers is None:
        all_layers = []
    for layer in network.children():
        if type(layer) == nn.Sequential: # if sequential layer, apply recursively to layers in sequential layer
            remove_sequential(layer, all_layers)
        if type(layer) in (DenseBlock, Transition): # if sequential layer, apply recursively to layers in sequential layer
            all_layers.append(layer)
        if list(layer.children()) == []: # if leaf node, add it to list
            all_layers.append(layer)
    return all_layers

def layer_description(model, x):
    for layer in remove_sequential(model):
        x = layer(x)
        print(layer.__class__.__name__,'Output shape:\t',x.shape)

# %%
layer_description(model, x = torch.randn((1,3,224,224)))
# Out:
# Conv2d Output shape:	 torch.Size([1, 64, 112, 112])
# BatchNorm2d Output shape:	 torch.Size([1, 64, 112, 112])
# ReLU Output shape:	 torch.Size([1, 64, 112, 112])
# MaxPool2d Output shape:	 torch.Size([1, 64, 56, 56])
# DenseBlock Output shape:	 torch.Size([1, 256, 56, 56])
# Transition Output shape:	 torch.Size([1, 128, 28, 28])
# DenseBlock Output shape:	 torch.Size([1, 512, 28, 28])
# Transition Output shape:	 torch.Size([1, 256, 14, 14])
# DenseBlock Output shape:	 torch.Size([1, 1024, 14, 14])
# Transition Output shape:	 torch.Size([1, 512, 7, 7])
# DenseBlock Output shape:	 torch.Size([1, 1024, 7, 7])
# BatchNorm2d Output shape:	 torch.Size([1, 1024, 7, 7])
# ReLU Output shape:	 torch.Size([1, 1024, 7, 7])
# AdaptiveAvgPool2d Output shape:	 torch.Size([1, 1024, 1, 1])
# Flatten Output shape:	 torch.Size([1, 1024])
# Linear Output shape:	 torch.Size([1, 10])

# %%
# x = torch.randn((1,3,224,224))
# torchviz.make_dot(model(x), params=dict(list(model.named_parameters()) + [('x', x)]))

# %%
# x = torch.randn((1,1,28,28))
# model = LeNet()

# with torch.onnx.set_training(model, False):
#     trace, _ = torch.jit.get_trace_graph(model, args=(x,))
# torchviz.make_dot_from_trace(trace)

# %%
torch.save(model, 'models/densenet.pt')
torch.save(model.features.dense_block1, 'models/denseblock.pt')
torch.save(model.features.dense_block1.denselayer1, 'models/denselayer.pt')
# Out:
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type DenseNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type DenseBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type DenseLayer. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Transition. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AdaptiveAvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
dummy_input = torch.randn((1,3,224,224))
torch.onnx.export(model, dummy_input, "models/densenet.onnx", verbose=True)
# Out:
# graph(%input.1 : Float(1, 3, 224, 224),
#       %features.conv0.weight : Float(64, 3, 7, 7),
#       %features.norm0.weight : Float(64),
#       %features.norm0.bias : Float(64),
#       %features.norm0.running_mean : Float(64),
#       %features.norm0.running_var : Float(64),
#       %features.norm0.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer1.norm1.weight : Float(64),
#       %features.dense_block1.denselayer1.norm1.bias : Float(64),
#       %features.dense_block1.denselayer1.norm1.running_mean : Float(64),
#       %features.dense_block1.denselayer1.norm1.running_var : Float(64),
#       %features.dense_block1.denselayer1.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer1.conv1.weight : Float(128, 64, 1, 1),
#       %features.dense_block1.denselayer1.norm2.weight : Float(128),
#       %features.dense_block1.denselayer1.norm2.bias : Float(128),
#       %features.dense_block1.denselayer1.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer1.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer1.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer1.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block1.denselayer2.norm1.weight : Float(96),
#       %features.dense_block1.denselayer2.norm1.bias : Float(96),
#       %features.dense_block1.denselayer2.norm1.running_mean : Float(96),
#       %features.dense_block1.denselayer2.norm1.running_var : Float(96),
#       %features.dense_block1.denselayer2.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer2.conv1.weight : Float(128, 96, 1, 1),
#       %features.dense_block1.denselayer2.norm2.weight : Float(128),
#       %features.dense_block1.denselayer2.norm2.bias : Float(128),
#       %features.dense_block1.denselayer2.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer2.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer2.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer2.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block1.denselayer3.norm1.weight : Float(128),
#       %features.dense_block1.denselayer3.norm1.bias : Float(128),
#       %features.dense_block1.denselayer3.norm1.running_mean : Float(128),
#       %features.dense_block1.denselayer3.norm1.running_var : Float(128),
#       %features.dense_block1.denselayer3.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer3.conv1.weight : Float(128, 128, 1, 1),
#       %features.dense_block1.denselayer3.norm2.weight : Float(128),
#       %features.dense_block1.denselayer3.norm2.bias : Float(128),
#       %features.dense_block1.denselayer3.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer3.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer3.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer3.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block1.denselayer4.norm1.weight : Float(160),
#       %features.dense_block1.denselayer4.norm1.bias : Float(160),
#       %features.dense_block1.denselayer4.norm1.running_mean : Float(160),
#       %features.dense_block1.denselayer4.norm1.running_var : Float(160),
#       %features.dense_block1.denselayer4.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer4.conv1.weight : Float(128, 160, 1, 1),
#       %features.dense_block1.denselayer4.norm2.weight : Float(128),
#       %features.dense_block1.denselayer4.norm2.bias : Float(128),
#       %features.dense_block1.denselayer4.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer4.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer4.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer4.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block1.denselayer5.norm1.weight : Float(192),
#       %features.dense_block1.denselayer5.norm1.bias : Float(192),
#       %features.dense_block1.denselayer5.norm1.running_mean : Float(192),
#       %features.dense_block1.denselayer5.norm1.running_var : Float(192),
#       %features.dense_block1.denselayer5.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer5.conv1.weight : Float(128, 192, 1, 1),
#       %features.dense_block1.denselayer5.norm2.weight : Float(128),
#       %features.dense_block1.denselayer5.norm2.bias : Float(128),
#       %features.dense_block1.denselayer5.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer5.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer5.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer5.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block1.denselayer6.norm1.weight : Float(224),
#       %features.dense_block1.denselayer6.norm1.bias : Float(224),
#       %features.dense_block1.denselayer6.norm1.running_mean : Float(224),
#       %features.dense_block1.denselayer6.norm1.running_var : Float(224),
#       %features.dense_block1.denselayer6.norm1.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer6.conv1.weight : Float(128, 224, 1, 1),
#       %features.dense_block1.denselayer6.norm2.weight : Float(128),
#       %features.dense_block1.denselayer6.norm2.bias : Float(128),
#       %features.dense_block1.denselayer6.norm2.running_mean : Float(128),
#       %features.dense_block1.denselayer6.norm2.running_var : Float(128),
#       %features.dense_block1.denselayer6.norm2.num_batches_tracked : Long(),
#       %features.dense_block1.denselayer6.conv2.weight : Float(32, 128, 3, 3),
#       %features.transition1.norm.weight : Float(256),
#       %features.transition1.norm.bias : Float(256),
#       %features.transition1.norm.running_mean : Float(256),
#       %features.transition1.norm.running_var : Float(256),
#       %features.transition1.norm.num_batches_tracked : Long(),
#       %features.transition1.conv.weight : Float(128, 256, 1, 1),
#       %features.transition1.conv.bias : Float(128),
#       %features.dense_block2.denselayer1.norm1.weight : Float(128),
#       %features.dense_block2.denselayer1.norm1.bias : Float(128),
#       %features.dense_block2.denselayer1.norm1.running_mean : Float(128),
#       %features.dense_block2.denselayer1.norm1.running_var : Float(128),
#       %features.dense_block2.denselayer1.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer1.conv1.weight : Float(128, 128, 1, 1),
#       %features.dense_block2.denselayer1.norm2.weight : Float(128),
#       %features.dense_block2.denselayer1.norm2.bias : Float(128),
#       %features.dense_block2.denselayer1.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer1.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer1.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer1.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer2.norm1.weight : Float(160),
#       %features.dense_block2.denselayer2.norm1.bias : Float(160),
#       %features.dense_block2.denselayer2.norm1.running_mean : Float(160),
#       %features.dense_block2.denselayer2.norm1.running_var : Float(160),
#       %features.dense_block2.denselayer2.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer2.conv1.weight : Float(128, 160, 1, 1),
#       %features.dense_block2.denselayer2.norm2.weight : Float(128),
#       %features.dense_block2.denselayer2.norm2.bias : Float(128),
#       %features.dense_block2.denselayer2.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer2.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer2.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer2.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer3.norm1.weight : Float(192),
#       %features.dense_block2.denselayer3.norm1.bias : Float(192),
#       %features.dense_block2.denselayer3.norm1.running_mean : Float(192),
#       %features.dense_block2.denselayer3.norm1.running_var : Float(192),
#       %features.dense_block2.denselayer3.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer3.conv1.weight : Float(128, 192, 1, 1),
#       %features.dense_block2.denselayer3.norm2.weight : Float(128),
#       %features.dense_block2.denselayer3.norm2.bias : Float(128),
#       %features.dense_block2.denselayer3.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer3.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer3.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer3.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer4.norm1.weight : Float(224),
#       %features.dense_block2.denselayer4.norm1.bias : Float(224),
#       %features.dense_block2.denselayer4.norm1.running_mean : Float(224),
#       %features.dense_block2.denselayer4.norm1.running_var : Float(224),
#       %features.dense_block2.denselayer4.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer4.conv1.weight : Float(128, 224, 1, 1),
#       %features.dense_block2.denselayer4.norm2.weight : Float(128),
#       %features.dense_block2.denselayer4.norm2.bias : Float(128),
#       %features.dense_block2.denselayer4.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer4.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer4.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer4.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer5.norm1.weight : Float(256),
#       %features.dense_block2.denselayer5.norm1.bias : Float(256),
#       %features.dense_block2.denselayer5.norm1.running_mean : Float(256),
#       %features.dense_block2.denselayer5.norm1.running_var : Float(256),
#       %features.dense_block2.denselayer5.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer5.conv1.weight : Float(128, 256, 1, 1),
#       %features.dense_block2.denselayer5.norm2.weight : Float(128),
#       %features.dense_block2.denselayer5.norm2.bias : Float(128),
#       %features.dense_block2.denselayer5.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer5.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer5.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer5.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer6.norm1.weight : Float(288),
#       %features.dense_block2.denselayer6.norm1.bias : Float(288),
#       %features.dense_block2.denselayer6.norm1.running_mean : Float(288),
#       %features.dense_block2.denselayer6.norm1.running_var : Float(288),
#       %features.dense_block2.denselayer6.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer6.conv1.weight : Float(128, 288, 1, 1),
#       %features.dense_block2.denselayer6.norm2.weight : Float(128),
#       %features.dense_block2.denselayer6.norm2.bias : Float(128),
#       %features.dense_block2.denselayer6.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer6.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer6.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer6.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer7.norm1.weight : Float(320),
#       %features.dense_block2.denselayer7.norm1.bias : Float(320),
#       %features.dense_block2.denselayer7.norm1.running_mean : Float(320),
#       %features.dense_block2.denselayer7.norm1.running_var : Float(320),
#       %features.dense_block2.denselayer7.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer7.conv1.weight : Float(128, 320, 1, 1),
#       %features.dense_block2.denselayer7.norm2.weight : Float(128),
#       %features.dense_block2.denselayer7.norm2.bias : Float(128),
#       %features.dense_block2.denselayer7.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer7.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer7.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer7.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer8.norm1.weight : Float(352),
#       %features.dense_block2.denselayer8.norm1.bias : Float(352),
#       %features.dense_block2.denselayer8.norm1.running_mean : Float(352),
#       %features.dense_block2.denselayer8.norm1.running_var : Float(352),
#       %features.dense_block2.denselayer8.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer8.conv1.weight : Float(128, 352, 1, 1),
#       %features.dense_block2.denselayer8.norm2.weight : Float(128),
#       %features.dense_block2.denselayer8.norm2.bias : Float(128),
#       %features.dense_block2.denselayer8.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer8.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer8.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer8.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer9.norm1.weight : Float(384),
#       %features.dense_block2.denselayer9.norm1.bias : Float(384),
#       %features.dense_block2.denselayer9.norm1.running_mean : Float(384),
#       %features.dense_block2.denselayer9.norm1.running_var : Float(384),
#       %features.dense_block2.denselayer9.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer9.conv1.weight : Float(128, 384, 1, 1),
#       %features.dense_block2.denselayer9.norm2.weight : Float(128),
#       %features.dense_block2.denselayer9.norm2.bias : Float(128),
#       %features.dense_block2.denselayer9.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer9.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer9.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer9.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer10.norm1.weight : Float(416),
#       %features.dense_block2.denselayer10.norm1.bias : Float(416),
#       %features.dense_block2.denselayer10.norm1.running_mean : Float(416),
#       %features.dense_block2.denselayer10.norm1.running_var : Float(416),
#       %features.dense_block2.denselayer10.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer10.conv1.weight : Float(128, 416, 1, 1),
#       %features.dense_block2.denselayer10.norm2.weight : Float(128),
#       %features.dense_block2.denselayer10.norm2.bias : Float(128),
#       %features.dense_block2.denselayer10.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer10.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer10.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer10.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer11.norm1.weight : Float(448),
#       %features.dense_block2.denselayer11.norm1.bias : Float(448),
#       %features.dense_block2.denselayer11.norm1.running_mean : Float(448),
#       %features.dense_block2.denselayer11.norm1.running_var : Float(448),
#       %features.dense_block2.denselayer11.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer11.conv1.weight : Float(128, 448, 1, 1),
#       %features.dense_block2.denselayer11.norm2.weight : Float(128),
#       %features.dense_block2.denselayer11.norm2.bias : Float(128),
#       %features.dense_block2.denselayer11.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer11.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer11.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer11.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block2.denselayer12.norm1.weight : Float(480),
#       %features.dense_block2.denselayer12.norm1.bias : Float(480),
#       %features.dense_block2.denselayer12.norm1.running_mean : Float(480),
#       %features.dense_block2.denselayer12.norm1.running_var : Float(480),
#       %features.dense_block2.denselayer12.norm1.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer12.conv1.weight : Float(128, 480, 1, 1),
#       %features.dense_block2.denselayer12.norm2.weight : Float(128),
#       %features.dense_block2.denselayer12.norm2.bias : Float(128),
#       %features.dense_block2.denselayer12.norm2.running_mean : Float(128),
#       %features.dense_block2.denselayer12.norm2.running_var : Float(128),
#       %features.dense_block2.denselayer12.norm2.num_batches_tracked : Long(),
#       %features.dense_block2.denselayer12.conv2.weight : Float(32, 128, 3, 3),
#       %features.transition2.norm.weight : Float(512),
#       %features.transition2.norm.bias : Float(512),
#       %features.transition2.norm.running_mean : Float(512),
#       %features.transition2.norm.running_var : Float(512),
#       %features.transition2.norm.num_batches_tracked : Long(),
#       %features.transition2.conv.weight : Float(256, 512, 1, 1),
#       %features.transition2.conv.bias : Float(256),
#       %features.dense_block3.denselayer1.norm1.weight : Float(256),
#       %features.dense_block3.denselayer1.norm1.bias : Float(256),
#       %features.dense_block3.denselayer1.norm1.running_mean : Float(256),
#       %features.dense_block3.denselayer1.norm1.running_var : Float(256),
#       %features.dense_block3.denselayer1.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer1.conv1.weight : Float(128, 256, 1, 1),
#       %features.dense_block3.denselayer1.norm2.weight : Float(128),
#       %features.dense_block3.denselayer1.norm2.bias : Float(128),
#       %features.dense_block3.denselayer1.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer1.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer1.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer1.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer2.norm1.weight : Float(288),
#       %features.dense_block3.denselayer2.norm1.bias : Float(288),
#       %features.dense_block3.denselayer2.norm1.running_mean : Float(288),
#       %features.dense_block3.denselayer2.norm1.running_var : Float(288),
#       %features.dense_block3.denselayer2.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer2.conv1.weight : Float(128, 288, 1, 1),
#       %features.dense_block3.denselayer2.norm2.weight : Float(128),
#       %features.dense_block3.denselayer2.norm2.bias : Float(128),
#       %features.dense_block3.denselayer2.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer2.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer2.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer2.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer3.norm1.weight : Float(320),
#       %features.dense_block3.denselayer3.norm1.bias : Float(320),
#       %features.dense_block3.denselayer3.norm1.running_mean : Float(320),
#       %features.dense_block3.denselayer3.norm1.running_var : Float(320),
#       %features.dense_block3.denselayer3.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer3.conv1.weight : Float(128, 320, 1, 1),
#       %features.dense_block3.denselayer3.norm2.weight : Float(128),
#       %features.dense_block3.denselayer3.norm2.bias : Float(128),
#       %features.dense_block3.denselayer3.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer3.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer3.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer3.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer4.norm1.weight : Float(352),
#       %features.dense_block3.denselayer4.norm1.bias : Float(352),
#       %features.dense_block3.denselayer4.norm1.running_mean : Float(352),
#       %features.dense_block3.denselayer4.norm1.running_var : Float(352),
#       %features.dense_block3.denselayer4.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer4.conv1.weight : Float(128, 352, 1, 1),
#       %features.dense_block3.denselayer4.norm2.weight : Float(128),
#       %features.dense_block3.denselayer4.norm2.bias : Float(128),
#       %features.dense_block3.denselayer4.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer4.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer4.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer4.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer5.norm1.weight : Float(384),
#       %features.dense_block3.denselayer5.norm1.bias : Float(384),
#       %features.dense_block3.denselayer5.norm1.running_mean : Float(384),
#       %features.dense_block3.denselayer5.norm1.running_var : Float(384),
#       %features.dense_block3.denselayer5.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer5.conv1.weight : Float(128, 384, 1, 1),
#       %features.dense_block3.denselayer5.norm2.weight : Float(128),
#       %features.dense_block3.denselayer5.norm2.bias : Float(128),
#       %features.dense_block3.denselayer5.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer5.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer5.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer5.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer6.norm1.weight : Float(416),
#       %features.dense_block3.denselayer6.norm1.bias : Float(416),
#       %features.dense_block3.denselayer6.norm1.running_mean : Float(416),
#       %features.dense_block3.denselayer6.norm1.running_var : Float(416),
#       %features.dense_block3.denselayer6.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer6.conv1.weight : Float(128, 416, 1, 1),
#       %features.dense_block3.denselayer6.norm2.weight : Float(128),
#       %features.dense_block3.denselayer6.norm2.bias : Float(128),
#       %features.dense_block3.denselayer6.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer6.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer6.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer6.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer7.norm1.weight : Float(448),
#       %features.dense_block3.denselayer7.norm1.bias : Float(448),
#       %features.dense_block3.denselayer7.norm1.running_mean : Float(448),
#       %features.dense_block3.denselayer7.norm1.running_var : Float(448),
#       %features.dense_block3.denselayer7.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer7.conv1.weight : Float(128, 448, 1, 1),
#       %features.dense_block3.denselayer7.norm2.weight : Float(128),
#       %features.dense_block3.denselayer7.norm2.bias : Float(128),
#       %features.dense_block3.denselayer7.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer7.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer7.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer7.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer8.norm1.weight : Float(480),
#       %features.dense_block3.denselayer8.norm1.bias : Float(480),
#       %features.dense_block3.denselayer8.norm1.running_mean : Float(480),
#       %features.dense_block3.denselayer8.norm1.running_var : Float(480),
#       %features.dense_block3.denselayer8.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer8.conv1.weight : Float(128, 480, 1, 1),
#       %features.dense_block3.denselayer8.norm2.weight : Float(128),
#       %features.dense_block3.denselayer8.norm2.bias : Float(128),
#       %features.dense_block3.denselayer8.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer8.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer8.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer8.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer9.norm1.weight : Float(512),
#       %features.dense_block3.denselayer9.norm1.bias : Float(512),
#       %features.dense_block3.denselayer9.norm1.running_mean : Float(512),
#       %features.dense_block3.denselayer9.norm1.running_var : Float(512),
#       %features.dense_block3.denselayer9.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer9.conv1.weight : Float(128, 512, 1, 1),
#       %features.dense_block3.denselayer9.norm2.weight : Float(128),
#       %features.dense_block3.denselayer9.norm2.bias : Float(128),
#       %features.dense_block3.denselayer9.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer9.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer9.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer9.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer10.norm1.weight : Float(544),
#       %features.dense_block3.denselayer10.norm1.bias : Float(544),
#       %features.dense_block3.denselayer10.norm1.running_mean : Float(544),
#       %features.dense_block3.denselayer10.norm1.running_var : Float(544),
#       %features.dense_block3.denselayer10.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer10.conv1.weight : Float(128, 544, 1, 1),
#       %features.dense_block3.denselayer10.norm2.weight : Float(128),
#       %features.dense_block3.denselayer10.norm2.bias : Float(128),
#       %features.dense_block3.denselayer10.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer10.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer10.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer10.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer11.norm1.weight : Float(576),
#       %features.dense_block3.denselayer11.norm1.bias : Float(576),
#       %features.dense_block3.denselayer11.norm1.running_mean : Float(576),
#       %features.dense_block3.denselayer11.norm1.running_var : Float(576),
#       %features.dense_block3.denselayer11.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer11.conv1.weight : Float(128, 576, 1, 1),
#       %features.dense_block3.denselayer11.norm2.weight : Float(128),
#       %features.dense_block3.denselayer11.norm2.bias : Float(128),
#       %features.dense_block3.denselayer11.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer11.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer11.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer11.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer12.norm1.weight : Float(608),
#       %features.dense_block3.denselayer12.norm1.bias : Float(608),
#       %features.dense_block3.denselayer12.norm1.running_mean : Float(608),
#       %features.dense_block3.denselayer12.norm1.running_var : Float(608),
#       %features.dense_block3.denselayer12.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer12.conv1.weight : Float(128, 608, 1, 1),
#       %features.dense_block3.denselayer12.norm2.weight : Float(128),
#       %features.dense_block3.denselayer12.norm2.bias : Float(128),
#       %features.dense_block3.denselayer12.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer12.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer12.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer12.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer13.norm1.weight : Float(640),
#       %features.dense_block3.denselayer13.norm1.bias : Float(640),
#       %features.dense_block3.denselayer13.norm1.running_mean : Float(640),
#       %features.dense_block3.denselayer13.norm1.running_var : Float(640),
#       %features.dense_block3.denselayer13.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer13.conv1.weight : Float(128, 640, 1, 1),
#       %features.dense_block3.denselayer13.norm2.weight : Float(128),
#       %features.dense_block3.denselayer13.norm2.bias : Float(128),
#       %features.dense_block3.denselayer13.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer13.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer13.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer13.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer14.norm1.weight : Float(672),
#       %features.dense_block3.denselayer14.norm1.bias : Float(672),
#       %features.dense_block3.denselayer14.norm1.running_mean : Float(672),
#       %features.dense_block3.denselayer14.norm1.running_var : Float(672),
#       %features.dense_block3.denselayer14.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer14.conv1.weight : Float(128, 672, 1, 1),
#       %features.dense_block3.denselayer14.norm2.weight : Float(128),
#       %features.dense_block3.denselayer14.norm2.bias : Float(128),
#       %features.dense_block3.denselayer14.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer14.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer14.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer14.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer15.norm1.weight : Float(704),
#       %features.dense_block3.denselayer15.norm1.bias : Float(704),
#       %features.dense_block3.denselayer15.norm1.running_mean : Float(704),
#       %features.dense_block3.denselayer15.norm1.running_var : Float(704),
#       %features.dense_block3.denselayer15.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer15.conv1.weight : Float(128, 704, 1, 1),
#       %features.dense_block3.denselayer15.norm2.weight : Float(128),
#       %features.dense_block3.denselayer15.norm2.bias : Float(128),
#       %features.dense_block3.denselayer15.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer15.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer15.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer15.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer16.norm1.weight : Float(736),
#       %features.dense_block3.denselayer16.norm1.bias : Float(736),
#       %features.dense_block3.denselayer16.norm1.running_mean : Float(736),
#       %features.dense_block3.denselayer16.norm1.running_var : Float(736),
#       %features.dense_block3.denselayer16.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer16.conv1.weight : Float(128, 736, 1, 1),
#       %features.dense_block3.denselayer16.norm2.weight : Float(128),
#       %features.dense_block3.denselayer16.norm2.bias : Float(128),
#       %features.dense_block3.denselayer16.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer16.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer16.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer16.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer17.norm1.weight : Float(768),
#       %features.dense_block3.denselayer17.norm1.bias : Float(768),
#       %features.dense_block3.denselayer17.norm1.running_mean : Float(768),
#       %features.dense_block3.denselayer17.norm1.running_var : Float(768),
#       %features.dense_block3.denselayer17.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer17.conv1.weight : Float(128, 768, 1, 1),
#       %features.dense_block3.denselayer17.norm2.weight : Float(128),
#       %features.dense_block3.denselayer17.norm2.bias : Float(128),
#       %features.dense_block3.denselayer17.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer17.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer17.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer17.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer18.norm1.weight : Float(800),
#       %features.dense_block3.denselayer18.norm1.bias : Float(800),
#       %features.dense_block3.denselayer18.norm1.running_mean : Float(800),
#       %features.dense_block3.denselayer18.norm1.running_var : Float(800),
#       %features.dense_block3.denselayer18.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer18.conv1.weight : Float(128, 800, 1, 1),
#       %features.dense_block3.denselayer18.norm2.weight : Float(128),
#       %features.dense_block3.denselayer18.norm2.bias : Float(128),
#       %features.dense_block3.denselayer18.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer18.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer18.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer18.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer19.norm1.weight : Float(832),
#       %features.dense_block3.denselayer19.norm1.bias : Float(832),
#       %features.dense_block3.denselayer19.norm1.running_mean : Float(832),
#       %features.dense_block3.denselayer19.norm1.running_var : Float(832),
#       %features.dense_block3.denselayer19.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer19.conv1.weight : Float(128, 832, 1, 1),
#       %features.dense_block3.denselayer19.norm2.weight : Float(128),
#       %features.dense_block3.denselayer19.norm2.bias : Float(128),
#       %features.dense_block3.denselayer19.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer19.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer19.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer19.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer20.norm1.weight : Float(864),
#       %features.dense_block3.denselayer20.norm1.bias : Float(864),
#       %features.dense_block3.denselayer20.norm1.running_mean : Float(864),
#       %features.dense_block3.denselayer20.norm1.running_var : Float(864),
#       %features.dense_block3.denselayer20.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer20.conv1.weight : Float(128, 864, 1, 1),
#       %features.dense_block3.denselayer20.norm2.weight : Float(128),
#       %features.dense_block3.denselayer20.norm2.bias : Float(128),
#       %features.dense_block3.denselayer20.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer20.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer20.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer20.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer21.norm1.weight : Float(896),
#       %features.dense_block3.denselayer21.norm1.bias : Float(896),
#       %features.dense_block3.denselayer21.norm1.running_mean : Float(896),
#       %features.dense_block3.denselayer21.norm1.running_var : Float(896),
#       %features.dense_block3.denselayer21.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer21.conv1.weight : Float(128, 896, 1, 1),
#       %features.dense_block3.denselayer21.norm2.weight : Float(128),
#       %features.dense_block3.denselayer21.norm2.bias : Float(128),
#       %features.dense_block3.denselayer21.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer21.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer21.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer21.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer22.norm1.weight : Float(928),
#       %features.dense_block3.denselayer22.norm1.bias : Float(928),
#       %features.dense_block3.denselayer22.norm1.running_mean : Float(928),
#       %features.dense_block3.denselayer22.norm1.running_var : Float(928),
#       %features.dense_block3.denselayer22.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer22.conv1.weight : Float(128, 928, 1, 1),
#       %features.dense_block3.denselayer22.norm2.weight : Float(128),
#       %features.dense_block3.denselayer22.norm2.bias : Float(128),
#       %features.dense_block3.denselayer22.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer22.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer22.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer22.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer23.norm1.weight : Float(960),
#       %features.dense_block3.denselayer23.norm1.bias : Float(960),
#       %features.dense_block3.denselayer23.norm1.running_mean : Float(960),
#       %features.dense_block3.denselayer23.norm1.running_var : Float(960),
#       %features.dense_block3.denselayer23.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer23.conv1.weight : Float(128, 960, 1, 1),
#       %features.dense_block3.denselayer23.norm2.weight : Float(128),
#       %features.dense_block3.denselayer23.norm2.bias : Float(128),
#       %features.dense_block3.denselayer23.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer23.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer23.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer23.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block3.denselayer24.norm1.weight : Float(992),
#       %features.dense_block3.denselayer24.norm1.bias : Float(992),
#       %features.dense_block3.denselayer24.norm1.running_mean : Float(992),
#       %features.dense_block3.denselayer24.norm1.running_var : Float(992),
#       %features.dense_block3.denselayer24.norm1.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer24.conv1.weight : Float(128, 992, 1, 1),
#       %features.dense_block3.denselayer24.norm2.weight : Float(128),
#       %features.dense_block3.denselayer24.norm2.bias : Float(128),
#       %features.dense_block3.denselayer24.norm2.running_mean : Float(128),
#       %features.dense_block3.denselayer24.norm2.running_var : Float(128),
#       %features.dense_block3.denselayer24.norm2.num_batches_tracked : Long(),
#       %features.dense_block3.denselayer24.conv2.weight : Float(32, 128, 3, 3),
#       %features.transition3.norm.weight : Float(1024),
#       %features.transition3.norm.bias : Float(1024),
#       %features.transition3.norm.running_mean : Float(1024),
#       %features.transition3.norm.running_var : Float(1024),
#       %features.transition3.norm.num_batches_tracked : Long(),
#       %features.transition3.conv.weight : Float(512, 1024, 1, 1),
#       %features.transition3.conv.bias : Float(512),
#       %features.dense_block4.denselayer1.norm1.weight : Float(512),
#       %features.dense_block4.denselayer1.norm1.bias : Float(512),
#       %features.dense_block4.denselayer1.norm1.running_mean : Float(512),
#       %features.dense_block4.denselayer1.norm1.running_var : Float(512),
#       %features.dense_block4.denselayer1.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer1.conv1.weight : Float(128, 512, 1, 1),
#       %features.dense_block4.denselayer1.norm2.weight : Float(128),
#       %features.dense_block4.denselayer1.norm2.bias : Float(128),
#       %features.dense_block4.denselayer1.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer1.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer1.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer1.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer2.norm1.weight : Float(544),
#       %features.dense_block4.denselayer2.norm1.bias : Float(544),
#       %features.dense_block4.denselayer2.norm1.running_mean : Float(544),
#       %features.dense_block4.denselayer2.norm1.running_var : Float(544),
#       %features.dense_block4.denselayer2.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer2.conv1.weight : Float(128, 544, 1, 1),
#       %features.dense_block4.denselayer2.norm2.weight : Float(128),
#       %features.dense_block4.denselayer2.norm2.bias : Float(128),
#       %features.dense_block4.denselayer2.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer2.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer2.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer2.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer3.norm1.weight : Float(576),
#       %features.dense_block4.denselayer3.norm1.bias : Float(576),
#       %features.dense_block4.denselayer3.norm1.running_mean : Float(576),
#       %features.dense_block4.denselayer3.norm1.running_var : Float(576),
#       %features.dense_block4.denselayer3.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer3.conv1.weight : Float(128, 576, 1, 1),
#       %features.dense_block4.denselayer3.norm2.weight : Float(128),
#       %features.dense_block4.denselayer3.norm2.bias : Float(128),
#       %features.dense_block4.denselayer3.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer3.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer3.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer3.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer4.norm1.weight : Float(608),
#       %features.dense_block4.denselayer4.norm1.bias : Float(608),
#       %features.dense_block4.denselayer4.norm1.running_mean : Float(608),
#       %features.dense_block4.denselayer4.norm1.running_var : Float(608),
#       %features.dense_block4.denselayer4.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer4.conv1.weight : Float(128, 608, 1, 1),
#       %features.dense_block4.denselayer4.norm2.weight : Float(128),
#       %features.dense_block4.denselayer4.norm2.bias : Float(128),
#       %features.dense_block4.denselayer4.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer4.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer4.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer4.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer5.norm1.weight : Float(640),
#       %features.dense_block4.denselayer5.norm1.bias : Float(640),
#       %features.dense_block4.denselayer5.norm1.running_mean : Float(640),
#       %features.dense_block4.denselayer5.norm1.running_var : Float(640),
#       %features.dense_block4.denselayer5.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer5.conv1.weight : Float(128, 640, 1, 1),
#       %features.dense_block4.denselayer5.norm2.weight : Float(128),
#       %features.dense_block4.denselayer5.norm2.bias : Float(128),
#       %features.dense_block4.denselayer5.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer5.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer5.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer5.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer6.norm1.weight : Float(672),
#       %features.dense_block4.denselayer6.norm1.bias : Float(672),
#       %features.dense_block4.denselayer6.norm1.running_mean : Float(672),
#       %features.dense_block4.denselayer6.norm1.running_var : Float(672),
#       %features.dense_block4.denselayer6.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer6.conv1.weight : Float(128, 672, 1, 1),
#       %features.dense_block4.denselayer6.norm2.weight : Float(128),
#       %features.dense_block4.denselayer6.norm2.bias : Float(128),
#       %features.dense_block4.denselayer6.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer6.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer6.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer6.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer7.norm1.weight : Float(704),
#       %features.dense_block4.denselayer7.norm1.bias : Float(704),
#       %features.dense_block4.denselayer7.norm1.running_mean : Float(704),
#       %features.dense_block4.denselayer7.norm1.running_var : Float(704),
#       %features.dense_block4.denselayer7.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer7.conv1.weight : Float(128, 704, 1, 1),
#       %features.dense_block4.denselayer7.norm2.weight : Float(128),
#       %features.dense_block4.denselayer7.norm2.bias : Float(128),
#       %features.dense_block4.denselayer7.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer7.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer7.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer7.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer8.norm1.weight : Float(736),
#       %features.dense_block4.denselayer8.norm1.bias : Float(736),
#       %features.dense_block4.denselayer8.norm1.running_mean : Float(736),
#       %features.dense_block4.denselayer8.norm1.running_var : Float(736),
#       %features.dense_block4.denselayer8.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer8.conv1.weight : Float(128, 736, 1, 1),
#       %features.dense_block4.denselayer8.norm2.weight : Float(128),
#       %features.dense_block4.denselayer8.norm2.bias : Float(128),
#       %features.dense_block4.denselayer8.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer8.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer8.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer8.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer9.norm1.weight : Float(768),
#       %features.dense_block4.denselayer9.norm1.bias : Float(768),
#       %features.dense_block4.denselayer9.norm1.running_mean : Float(768),
#       %features.dense_block4.denselayer9.norm1.running_var : Float(768),
#       %features.dense_block4.denselayer9.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer9.conv1.weight : Float(128, 768, 1, 1),
#       %features.dense_block4.denselayer9.norm2.weight : Float(128),
#       %features.dense_block4.denselayer9.norm2.bias : Float(128),
#       %features.dense_block4.denselayer9.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer9.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer9.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer9.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer10.norm1.weight : Float(800),
#       %features.dense_block4.denselayer10.norm1.bias : Float(800),
#       %features.dense_block4.denselayer10.norm1.running_mean : Float(800),
#       %features.dense_block4.denselayer10.norm1.running_var : Float(800),
#       %features.dense_block4.denselayer10.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer10.conv1.weight : Float(128, 800, 1, 1),
#       %features.dense_block4.denselayer10.norm2.weight : Float(128),
#       %features.dense_block4.denselayer10.norm2.bias : Float(128),
#       %features.dense_block4.denselayer10.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer10.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer10.norm2.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer10.conv2.weight : Float(32, 128, 3, 3),
#       %features.dense_block4.denselayer11.norm1.weight : Float(832),
#       %features.dense_block4.denselayer11.norm1.bias : Float(832),
#       %features.dense_block4.denselayer11.norm1.running_mean : Float(832),
#       %features.dense_block4.denselayer11.norm1.running_var : Float(832),
#       %features.dense_block4.denselayer11.norm1.num_batches_tracked : Long(),
#       %features.dense_block4.denselayer11.conv1.weight : Float(128, 832, 1, 1),
#       %features.dense_block4.denselayer11.norm2.weight : Float(128),
#       %features.dense_block4.denselayer11.norm2.bias : Float(128),
#       %features.dense_block4.denselayer11.norm2.running_mean : Float(128),
#       %features.dense_block4.denselayer11.norm2.running_var : Float(128),
#       %features.dense_block4.denselayer11.norm2.num_batches_tracked : Long(),
# ...
#   %1119 : Float(1, 832, 7, 7) = onnx::Relu(%1118), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer11]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1120 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1119, %features.dense_block4.denselayer11.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer11]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1121 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1120, %features.dense_block4.denselayer11.norm2.weight, %features.dense_block4.denselayer11.norm2.bias, %features.dense_block4.denselayer11.norm2.running_mean, %features.dense_block4.denselayer11.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer11]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1122 : Float(1, 128, 7, 7) = onnx::Relu(%1121), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer11]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1123 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1122, %features.dense_block4.denselayer11.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer11]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1124 : Float(1, 864, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12] # <ipython-input-3-e3e10a1aa745>:26:0
#   %1125 : Float(1, 864, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1124, %features.dense_block4.denselayer12.norm1.weight, %features.dense_block4.denselayer12.norm1.bias, %features.dense_block4.denselayer12.norm1.running_mean, %features.dense_block4.denselayer12.norm1.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/BatchNorm2d[norm1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1126 : Float(1, 864, 7, 7) = onnx::Relu(%1125), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1127 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1126, %features.dense_block4.denselayer12.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1128 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1127, %features.dense_block4.denselayer12.norm2.weight, %features.dense_block4.denselayer12.norm2.bias, %features.dense_block4.denselayer12.norm2.running_mean, %features.dense_block4.denselayer12.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1129 : Float(1, 128, 7, 7) = onnx::Relu(%1128), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1130 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1129, %features.dense_block4.denselayer12.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer12]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1131 : Float(1, 896, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123, %1130), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13] # <ipython-input-3-e3e10a1aa745>:26:0
#   %1132 : Float(1, 896, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1131, %features.dense_block4.denselayer13.norm1.weight, %features.dense_block4.denselayer13.norm1.bias, %features.dense_block4.denselayer13.norm1.running_mean, %features.dense_block4.denselayer13.norm1.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/BatchNorm2d[norm1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1133 : Float(1, 896, 7, 7) = onnx::Relu(%1132), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1134 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1133, %features.dense_block4.denselayer13.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1135 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1134, %features.dense_block4.denselayer13.norm2.weight, %features.dense_block4.denselayer13.norm2.bias, %features.dense_block4.denselayer13.norm2.running_mean, %features.dense_block4.denselayer13.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1136 : Float(1, 128, 7, 7) = onnx::Relu(%1135), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1137 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1136, %features.dense_block4.denselayer13.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer13]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1138 : Float(1, 928, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123, %1130, %1137), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14] # <ipython-input-3-e3e10a1aa745>:26:0
#   %1139 : Float(1, 928, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1138, %features.dense_block4.denselayer14.norm1.weight, %features.dense_block4.denselayer14.norm1.bias, %features.dense_block4.denselayer14.norm1.running_mean, %features.dense_block4.denselayer14.norm1.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/BatchNorm2d[norm1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1140 : Float(1, 928, 7, 7) = onnx::Relu(%1139), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1141 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1140, %features.dense_block4.denselayer14.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1142 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1141, %features.dense_block4.denselayer14.norm2.weight, %features.dense_block4.denselayer14.norm2.bias, %features.dense_block4.denselayer14.norm2.running_mean, %features.dense_block4.denselayer14.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1143 : Float(1, 128, 7, 7) = onnx::Relu(%1142), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1144 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1143, %features.dense_block4.denselayer14.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer14]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1145 : Float(1, 960, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123, %1130, %1137, %1144), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15] # <ipython-input-3-e3e10a1aa745>:26:0
#   %1146 : Float(1, 960, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1145, %features.dense_block4.denselayer15.norm1.weight, %features.dense_block4.denselayer15.norm1.bias, %features.dense_block4.denselayer15.norm1.running_mean, %features.dense_block4.denselayer15.norm1.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/BatchNorm2d[norm1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1147 : Float(1, 960, 7, 7) = onnx::Relu(%1146), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1148 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1147, %features.dense_block4.denselayer15.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1149 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1148, %features.dense_block4.denselayer15.norm2.weight, %features.dense_block4.denselayer15.norm2.bias, %features.dense_block4.denselayer15.norm2.running_mean, %features.dense_block4.denselayer15.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1150 : Float(1, 128, 7, 7) = onnx::Relu(%1149), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1151 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1150, %features.dense_block4.denselayer15.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer15]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1152 : Float(1, 992, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123, %1130, %1137, %1144, %1151), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16] # <ipython-input-3-e3e10a1aa745>:26:0
#   %1153 : Float(1, 992, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1152, %features.dense_block4.denselayer16.norm1.weight, %features.dense_block4.denselayer16.norm1.bias, %features.dense_block4.denselayer16.norm1.running_mean, %features.dense_block4.denselayer16.norm1.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/BatchNorm2d[norm1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1154 : Float(1, 992, 7, 7) = onnx::Relu(%1153), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/ReLU[relu1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1155 : Float(1, 128, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1154, %features.dense_block4.denselayer16.conv1.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/Conv2d[conv1] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1156 : Float(1, 128, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1155, %features.dense_block4.denselayer16.norm2.weight, %features.dense_block4.denselayer16.norm2.bias, %features.dense_block4.denselayer16.norm2.running_mean, %features.dense_block4.denselayer16.norm2.running_var), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/BatchNorm2d[norm2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1157 : Float(1, 128, 7, 7) = onnx::Relu(%1156), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/ReLU[relu2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1158 : Float(1, 32, 7, 7) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1157, %features.dense_block4.denselayer16.conv2.weight), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4]/DenseLayer[denselayer16]/Conv2d[conv2] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/conv.py:342:0
#   %1159 : Float(1, 1024, 7, 7) = onnx::Concat[axis=1](%1046, %1053, %1060, %1067, %1074, %1081, %1088, %1095, %1102, %1109, %1116, %1123, %1130, %1137, %1144, %1151, %1158), scope: DenseNet/Sequential[features]/DenseBlock[dense_block4] # <ipython-input-3-e3e10a1aa745>:50:0
#   %1160 : Float(1, 1024, 7, 7) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%1159, %final.norm5.weight, %final.norm5.bias, %final.norm5.running_mean, %final.norm5.running_var), scope: DenseNet/Sequential[final]/BatchNorm2d[norm5] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1670:0
#   %1161 : Float(1, 1024, 7, 7) = onnx::Relu(%1160), scope: DenseNet/Sequential[final]/ReLU[relu5] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:912:0
#   %1162 : Float(1, 1024, 1, 1) = onnx::GlobalAveragePool(%1161), scope: DenseNet/Sequential[final]/AdaptiveAvgPool2d[avgpool5] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:768:0
#   %1163 : Float(1, 1024) = onnx::Flatten[axis=1](%1162), scope: DenseNet/Sequential[final]/Flatten[flatten] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/flatten.py:29:0
#   %1164 : Float(1, 10) = onnx::Gemm[alpha=1, beta=1, transB=1](%1163, %final.linear.weight, %final.linear.bias), scope: DenseNet/Sequential[final]/Linear[linear] # /Users/ring/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:1370:0
#   return (%1164)
